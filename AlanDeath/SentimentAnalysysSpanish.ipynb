# %% [markdown]
# **sentiment-analysis-spanish 0.0.25**
#
# sentiment-spanish es una biblioteca de Python que utiliza redes neuronales convolucionales para predecir el sentimiento de oraciones en español. El modelo fue entrenado utilizando más de 800000 reseñas de usuarios de las páginas eltenedor, decathlon, tripadvisor, filmaffinity y ebay. Estas reseñas fueron extraídas utilizando web scraping con el proyecto opinion-reviews-scraper
#
# Usando la tasa en las reseñas de los usuarios entrenamos el modelo para que aprendiera del idioma en ellas. Para eso usamos las librerías Keras y Tensorflow. Logramos una precisión de validación (precisión sobre datos frescos, no utilizados para el entrenamiento) del 88%. Para más detalles sobre el entrenamiento del modelo de red neuronal, consulte el repositorio sentiment-analysis-model-neural-network

# %% [markdown]
# # 1. INSTALACION DEL PAQUETE Y PRUEBA DE ALGORITMO

# %%
#Install and use
#pip install sentiment-analysis-spanish
#You will also need keras and tensorflow
#pip install keras tensorflow

# %%
#IMPORTO PAQUETE 
from sentiment_analysis_spanish import sentiment_analysis
import pandas as pd

# %%
#Creo objeto y CORRO SENTIMIENTO ANALISIS
sentiment = sentiment_analysis.SentimentAnalysisSpanish()
print(sentiment.sentiment("🤦🏻‍♂️🤦🏻‍♂️🤦🏻‍♂️🤦🏻‍♂️🤦🏻‍♂️ gente de mierda"))
# Out:
# C:\Users\User\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:376: InconsistentVersionWarning: Trying to unpickle estimator CountVectorizer from version 0.23.2 when using version 1.5.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# C:\Users\User\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:376: InconsistentVersionWarning: Trying to unpickle estimator MultinomialNB from version 0.23.2 when using version 1.5.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 0.29557480691200605

# %%
#prueba 2
print(sentiment.sentiment("me gusta la tombola es genial"))
# Out:
# 0.9304396176531412

# %%
#prueba 3

text = "Este producto es una mierda"

#Analizando el texto

scores = sentiment.sentiment(text)
print('Sentiment: ', scores)
# Out:
# Sentiment:  0.07784833291715228

# %% [markdown]
# Salida y significado
#
# La función sentiment(text) devuelve un número entre 0 y 1. Esta es la probabilidad de que la variable de cadena text sea "positiva". Las probabilidades bajas significan que el texto es negativo (números cercanos a 0), las probabilidades altas (números cercanos a 1) significan que el texto es positivo. El espacio entre ellos corresponde a textos neutrales.

# %% [markdown]
# # 2.DATASET

# %%
df = pd.read_csv('Data/db_AGP_2019_sucesos.csv',encoding='UTF-8')
df
# Out:
#                        created_time.1       created_time.2  \
# 0        viernes, 19 de abril de 2019  30/12/1899 09:16:15
# 1         jueves, 18 de abril de 2019  30/12/1899 20:57:16
# 2      miércoles, 17 de abril de 2019  30/12/1899 07:37:30
# 3        viernes, 19 de abril de 2019  30/12/1899 09:16:15
# 4        viernes, 19 de abril de 2019  30/12/1899 09:16:15
# ...                               ...                  ...
# 55001     jueves, 18 de abril de 2019  30/12/1899 22:01:46
# 55002    viernes, 19 de abril de 2019  30/12/1899 12:35:28
# 55003     jueves, 18 de abril de 2019  30/12/1899 19:12:45
# 55004     jueves, 18 de abril de 2019  30/12/1899 19:12:45
# 55005  miércoles, 17 de abril de 2019  30/12/1899 10:36:04
#
#                                                  message  \
# 0      Velorio del ex presidente Alan García en la Ca...
# 1      Exequias del ex presidente Alan García en "La ...
# 2      🚨 Estamos en los exteriores del Hospital de Em...
# 3      Velorio del ex presidente Alan García en la Ca...
# 4      Velorio del ex presidente Alan García en la Ca...
# ...                                                  ...
# 55001  Hoy en portada de El Comercio ↓\r\n- Alan Garc...
# 55002  El féretro que lleva el cuerpo del ex presiden...
# 55003  Decenas de simpatizantes del Partido Aprista, ...
# 55004  Decenas de simpatizantes del Partido Aprista, ...
# 55005  Dirigencia aprista y presidente Martín Vizcarr...
#
#                                   id  \
# 0        71263708835_377868469727477
# 1        71263708835_276236269920595
# 2        71263708835_310239669653341
# 3        71263708835_377868469727477
# 4        71263708835_377868469727477
# ...                              ...
# 55001  71263708835_10157691724488836
# 55002    71263708835_567646733744707
# 55003  71263708835_10157691315508836
# 55004  71263708835_10157691315508836
# 55005    71263708835_384993168759830
#
#                 object_link.connections.comments.message      FECHA Y HORA
# 0                                                     🧐🧐   19/04/2019 9:16
# 1                                               🥺🥺🥺🥺🥺🥺🥺🥺  18/04/2019 20:57
# 2                                                      🥳   17/04/2019 7:37
# 3                                           🤷‍♀️🤷‍♀️🤷‍♀️   19/04/2019 9:16
# 4                                                   🤯🤯🤯🤯   19/04/2019 9:16
# ...                                                  ...               ...
# 55001  ! COMERCIO  ! Así saques en primera página al ...  18/04/2019 22:01
# 55002                 - XQ' NADIE PUEDE VER EL CADAVER ?  19/04/2019 12:35
# 55003  – 1985: 69 personas asesinadas en Accomarca.\r...  18/04/2019 19:12
# 55004  – 1985: 69 personas asesinadas en Accomarca.\r...  18/04/2019 19:12
# 55005  – 1985: 69 personas asesinadas en Accomarca.\r...  17/04/2019 10:36
#
# [55006 rows x 6 columns]

# %%
df.drop(columns=['created_time.1','created_time.2'],inplace=True)
df
# Out:
#                                                  message  \
# 0      Velorio del ex presidente Alan García en la Ca...
# 1      Exequias del ex presidente Alan García en "La ...
# 2      🚨 Estamos en los exteriores del Hospital de Em...
# 3      Velorio del ex presidente Alan García en la Ca...
# 4      Velorio del ex presidente Alan García en la Ca...
# ...                                                  ...
# 55001  Hoy en portada de El Comercio ↓\r\n- Alan Garc...
# 55002  El féretro que lleva el cuerpo del ex presiden...
# 55003  Decenas de simpatizantes del Partido Aprista, ...
# 55004  Decenas de simpatizantes del Partido Aprista, ...
# 55005  Dirigencia aprista y presidente Martín Vizcarr...
#
#                                   id  \
# 0        71263708835_377868469727477
# 1        71263708835_276236269920595
# 2        71263708835_310239669653341
# 3        71263708835_377868469727477
# 4        71263708835_377868469727477
# ...                              ...
# 55001  71263708835_10157691724488836
# 55002    71263708835_567646733744707
# 55003  71263708835_10157691315508836
# 55004  71263708835_10157691315508836
# 55005    71263708835_384993168759830
#
#                 object_link.connections.comments.message      FECHA Y HORA
# 0                                                     🧐🧐   19/04/2019 9:16
# 1                                               🥺🥺🥺🥺🥺🥺🥺🥺  18/04/2019 20:57
# 2                                                      🥳   17/04/2019 7:37
# 3                                           🤷‍♀️🤷‍♀️🤷‍♀️   19/04/2019 9:16
# 4                                                   🤯🤯🤯🤯   19/04/2019 9:16
# ...                                                  ...               ...
# 55001  ! COMERCIO  ! Así saques en primera página al ...  18/04/2019 22:01
# 55002                 - XQ' NADIE PUEDE VER EL CADAVER ?  19/04/2019 12:35
# 55003  – 1985: 69 personas asesinadas en Accomarca.\r...  18/04/2019 19:12
# 55004  – 1985: 69 personas asesinadas en Accomarca.\r...  18/04/2019 19:12
# 55005  – 1985: 69 personas asesinadas en Accomarca.\r...  17/04/2019 10:36
#
# [55006 rows x 4 columns]

# %%
df.rename({'created_time.1':'Hora tweet','message':'Tweet','object_link.connections.comments.message':'Comentarios','FECHA Y HORA':'Fecha y hora'},axis=1,inplace=True)

# %%
df["SentimientosPredecidos"] = df["Comentarios"].apply(sentiment.sentiment)

# %%
df
# Out:
#                                                    Tweet  \
# 0      Velorio del ex presidente Alan García en la Ca...
# 1      Exequias del ex presidente Alan García en "La ...
# 2      🚨 Estamos en los exteriores del Hospital de Em...
# 3      Velorio del ex presidente Alan García en la Ca...
# 4      Velorio del ex presidente Alan García en la Ca...
# ...                                                  ...
# 55001  Hoy en portada de El Comercio ↓\r\n- Alan Garc...
# 55002  El féretro que lleva el cuerpo del ex presiden...
# 55003  Decenas de simpatizantes del Partido Aprista, ...
# 55004  Decenas de simpatizantes del Partido Aprista, ...
# 55005  Dirigencia aprista y presidente Martín Vizcarr...
#
#                                   id  \
# 0        71263708835_377868469727477
# 1        71263708835_276236269920595
# 2        71263708835_310239669653341
# 3        71263708835_377868469727477
# 4        71263708835_377868469727477
# ...                              ...
# 55001  71263708835_10157691724488836
# 55002    71263708835_567646733744707
# 55003  71263708835_10157691315508836
# 55004  71263708835_10157691315508836
# 55005    71263708835_384993168759830
#
#                                              Comentarios      Fecha y hora  \
# 0                                                     🧐🧐   19/04/2019 9:16
# 1                                               🥺🥺🥺🥺🥺🥺🥺🥺  18/04/2019 20:57
# 2                                                      🥳   17/04/2019 7:37
# 3                                           🤷‍♀️🤷‍♀️🤷‍♀️   19/04/2019 9:16
# 4                                                   🤯🤯🤯🤯   19/04/2019 9:16
# ...                                                  ...               ...
# 55001  ! COMERCIO  ! Así saques en primera página al ...  18/04/2019 22:01
# 55002                 - XQ' NADIE PUEDE VER EL CADAVER ?  19/04/2019 12:35
# 55003  – 1985: 69 personas asesinadas en Accomarca.\r...  18/04/2019 19:12
# 55004  – 1985: 69 personas asesinadas en Accomarca.\r...  18/04/2019 19:12
# 55005  – 1985: 69 personas asesinadas en Accomarca.\r...  17/04/2019 10:36
#
#        SentimientosPredecidos
# 0                4.978923e-01
# 1                4.978923e-01
# 2                4.978923e-01
# 3                4.978923e-01
# 4                4.978923e-01
# ...                       ...
# 55001            1.591289e-05
# 55002            3.112629e-02
# 55003            3.854220e-15
# 55004            3.854220e-15
# 55005            1.039886e-16
#
# [55006 rows x 5 columns]

# %%
#Función para formatear el número 
def format_number(x):
    if isinstance(x, float):
        return '{:.10f}'.format(x)
    return x 

# Aplicar la función a la columna
df['SentimientosPredecidos'] = df['SentimientosPredecidos'].apply(format_number)

# %%
df
# Out:
#                                                    Tweet  \
# 0      Velorio del ex presidente Alan García en la Ca...
# 1      Exequias del ex presidente Alan García en "La ...
# 2      🚨 Estamos en los exteriores del Hospital de Em...
# 3      Velorio del ex presidente Alan García en la Ca...
# 4      Velorio del ex presidente Alan García en la Ca...
# ...                                                  ...
# 55001  Hoy en portada de El Comercio ↓\r\n- Alan Garc...
# 55002  El féretro que lleva el cuerpo del ex presiden...
# 55003  Decenas de simpatizantes del Partido Aprista, ...
# 55004  Decenas de simpatizantes del Partido Aprista, ...
# 55005  Dirigencia aprista y presidente Martín Vizcarr...
#
#                                   id  \
# 0        71263708835_377868469727477
# 1        71263708835_276236269920595
# 2        71263708835_310239669653341
# 3        71263708835_377868469727477
# 4        71263708835_377868469727477
# ...                              ...
# 55001  71263708835_10157691724488836
# 55002    71263708835_567646733744707
# 55003  71263708835_10157691315508836
# 55004  71263708835_10157691315508836
# 55005    71263708835_384993168759830
#
#                                               comentario      Fecha y hora  \
# 0                                                     🧐🧐   19/04/2019 9:16
# 1                                               🥺🥺🥺🥺🥺🥺🥺🥺  18/04/2019 20:57
# 2                                                      🥳   17/04/2019 7:37
# 3                                           🤷‍♀️🤷‍♀️🤷‍♀️   19/04/2019 9:16
# 4                                                   🤯🤯🤯🤯   19/04/2019 9:16
# ...                                                  ...               ...
# 55001  ! COMERCIO  ! Así saques en primera página al ...  18/04/2019 22:01
# 55002                 - XQ' NADIE PUEDE VER EL CADAVER ?  19/04/2019 12:35
# 55003  – 1985: 69 personas asesinadas en Accomarca.\r...  18/04/2019 19:12
# 55004  – 1985: 69 personas asesinadas en Accomarca.\r...  18/04/2019 19:12
# 55005  – 1985: 69 personas asesinadas en Accomarca.\r...  17/04/2019 10:36
#
#       SentimientosPredecidos
# 0               0.4978922592
# 1               0.4978922592
# 2               0.4978922592
# 3               0.4978922592
# 4               0.4978922592
# ...                      ...
# 55001           0.0000159129
# 55002           0.0311262949
# 55003           0.0000000000
# 55004           0.0000000000
# 55005           0.0000000000
#
# [55006 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55006 entries, 0 to 55005
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Tweet                   55006 non-null  object
#  1   id                      55006 non-null  object
#  2   comentario              55006 non-null  object
#  3   Fecha y hora            55006 non-null  object
#  4   SentimientosPredecidos  55006 non-null  float64
# dtypes: float64(1), object(4)
# memory usage: 2.1+ MB

# %%
df.to_csv('newarchivo.csv')
